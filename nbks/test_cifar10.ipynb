# %% [markdown]
# ## Initialization

# %%
# data processing
import numpy as np
import pandas as pd 
from collections import defaultdict

# data visualization
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
sns.set()

import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))

# Notebook auto reloads code. (Ref: http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython)
# %load_ext autoreload
# %autoreload 2
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# If using Google Colab
from google.colab import drive
BASE_PATH = '/content/drive'
drive.mount(BASE_PATH)

# change directory
import os
PROJECT_PATH = os.path.join(BASE_PATH, "MyDrive", "2021-09 Fall Semester", "ECBM 4040 Neural Network Deep Learning", "Project", "recreating-residual-attention-network")
os.chdir(PROJECT_PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import created modules
from src.models.ResidualAttentionNetwork import ResidualAttentionNetwork
from src.utils import generate_data

# %% [markdown]
# # Modelling

# %%
x_train, y_train, x_test, y_test, datagen = generate_data.get_cifar10(rotation_range=20,
                                                                      width_shift_range=0.2,
                                                                      height_shift_range=0.2,
                                                                      horizontal_flip=True,
                                                                      validation_split=0.2)

# %%
INPUT_SHAPE = x_train.shape[1:]
NUM_CLASS = y_train.shape[1]
BATCH_SIZE = 128
N_EPOCH = 10

# %%
ran_model = ResidualAttentionNetwork()
inputs = tf.keras.Input((32, 32, 3))
ran_model(inputs)
ran_model.summary()
# Out:
# Model: "residual_attention_network"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             multiple                  864
#
#  batch_normalization (BatchN  multiple                 128
#  ormalization)
#
#  re_lu (ReLU)                multiple                  0
#
#  residual_unit (ResidualUnit  multiple                 19520
#  )
#
#  attention_module (Attention  multiple                 347712
#  Module)
#
#  residual_unit_10 (ResidualU  multiple                 96384
#  nit)
#
#  attention_module_1 (Attenti  multiple                 957184
#  onModule)
#
#  residual_unit_17 (ResidualU  multiple                 381184
#  nit)
#
#  residual_unit_18 (ResidualU  multiple                 545024
#  nit)
#
#  residual_unit_19 (ResidualU  multiple                 545024
#  nit)
#
#  batch_normalization_65 (Bat  multiple                 2048
#  chNormalization)
#
#  re_lu_65 (ReLU)             multiple                  0
#
#  average_pooling2d (AverageP  multiple                 0
#  ooling2D)
#
#  flatten (Flatten)           multiple                  0
#
#  dense (Dense)               multiple                  16416
#
#  dense_1 (Dense)             multiple                  330
#
# =================================================================
# Total params: 2,911,818
# Trainable params: 2,895,370
# Non-trainable params: 16,448
# _________________________________________________________________

# %%
model = ran_model

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=['accuracy'])


history = model.fit(datagen.flow(x_train, y_train, batch_size=BATCH_SIZE, subset='training'), 
                    validation_data=datagen.flow(x_train, y_train, batch_size=BATCH_SIZE, subset='validation'),
                    epochs=N_EPOCH, verbose=1)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 113s 301ms/step - loss: 1.8861 - accuracy: 0.2893 - val_loss: 3.7587 - val_accuracy: 0.1202
# Epoch 2/10
# 313/313 [==============================] - 91s 292ms/step - loss: 1.5676 - accuracy: 0.4220 - val_loss: 1.7193 - val_accuracy: 0.3876
# Epoch 3/10
# 313/313 [==============================] - 91s 292ms/step - loss: 1.4207 - accuracy: 0.4807 - val_loss: 1.5338 - val_accuracy: 0.4494
# Epoch 4/10
# 313/313 [==============================] - 92s 292ms/step - loss: 1.3236 - accuracy: 0.5208 - val_loss: 1.4127 - val_accuracy: 0.4952
# Epoch 5/10
# 313/313 [==============================] - 92s 292ms/step - loss: 1.2350 - accuracy: 0.5516 - val_loss: 1.3896 - val_accuracy: 0.4981
# Epoch 6/10
# 313/313 [==============================] - 91s 292ms/step - loss: 1.1575 - accuracy: 0.5835 - val_loss: 1.4227 - val_accuracy: 0.4962
# Epoch 7/10
# 313/313 [==============================] - 91s 292ms/step - loss: 1.0904 - accuracy: 0.6090 - val_loss: 1.3489 - val_accuracy: 0.5528
# Epoch 8/10
# 313/313 [==============================] - 91s 292ms/step - loss: 1.0253 - accuracy: 0.6361 - val_loss: 1.6529 - val_accuracy: 0.4925
# Epoch 9/10
# 313/313 [==============================] - 91s 292ms/step - loss: 0.9740 - accuracy: 0.6538 - val_loss: 1.1142 - val_accuracy: 0.6103
# Epoch 10/10
# 313/313 [==============================] - 91s 292ms/step - loss: 0.9266 - accuracy: 0.6720 - val_loss: 1.1093 - val_accuracy: 0.6108

# %%
model = ResidualAttentionNetwork()

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=['accuracy'])


history = model.fit(datagen.flow(x_train, y_train, batch_size=BATCH_SIZE, subset='training'), 
                    validation_data=datagen.flow(x_train, y_train, batch_size=BATCH_SIZE, subset='validation'),
                    epochs=2, verbose=1)
# Out:
# Epoch 1/2
# 313/313 [==============================] - 103s 299ms/step - loss: 1.9042 - accuracy: 0.2879 - val_loss: 2.6524 - val_accuracy: 0.1348
# Epoch 2/2
# 313/313 [==============================] - 92s 294ms/step - loss: 1.5451 - accuracy: 0.4286 - val_loss: 1.7821 - val_accuracy: 0.3824
